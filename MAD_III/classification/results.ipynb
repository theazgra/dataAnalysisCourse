# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
dfTree = pd.read_csv('classification/DecisionTreeCache.csv', index_col=0)
dfNN = pd.read_csv('classification/mplc.csv', index_col=0)
dfSVC = pd.read_csv('classification/svm.csv', index_col=0)
df = pd.concat([dfTree,dfNN,dfSVC]).reset_index()
# df = df.set_index("Dataset")
df
# Out:
#             Dataset         Classifier  KFoldIndex     FitTime  \
# 0             dfNum    DecTree MSF=100           0    1.075743
# 1             dfNum    DecTree MSF=100           1    1.101148
# 2             dfNum    DecTree MSF=100           2    1.049477
# 3         dfNumNorm    DecTree MSF=100           0    1.114521
# 4         dfNumNorm    DecTree MSF=100           1    1.031433
# 5         dfNumNorm    DecTree MSF=100           2    1.050809
# 6      dfNumNormAll    DecTree MSF=100           0    1.059332
# 7      dfNumNormAll    DecTree MSF=100           1    1.103978
# 8      dfNumNormAll    DecTree MSF=100           2    1.080923
# 9         dfNumOnly    DecTree MSF=100           0    1.069072
# 10        dfNumOnly    DecTree MSF=100           1    1.020148
# 11        dfNumOnly    DecTree MSF=100           2    1.114013
# 12  dfNumOnly10Feat    DecTree MSF=100           0    0.899927
# 13  dfNumOnly10Feat    DecTree MSF=100           1    0.866539
# 14  dfNumOnly10Feat    DecTree MSF=100           2    0.852286
# 15  dfNumOnly20Feat    DecTree MSF=100           0    2.093759
# 16  dfNumOnly20Feat    DecTree MSF=100           1    1.855811
# 17  dfNumOnly20Feat    DecTree MSF=100           2    2.148961
# 18            dfNum    MLPC_tanh_(5,5)           0    5.739113
# 19            dfNum    MLPC_tanh_(5,5)           1   14.195107
# 20            dfNum    MLPC_tanh_(5,5)           2   10.313619
# 21        dfNumNorm    MLPC_tanh_(5,5)           0    6.305877
# 22        dfNumNorm    MLPC_tanh_(5,5)           1    6.352732
# 23        dfNumNorm    MLPC_tanh_(5,5)           2   13.320381
# 24     dfNumNormAll    MLPC_tanh_(5,5)           0   15.123451
# 25     dfNumNormAll    MLPC_tanh_(5,5)           1   12.209073
# 26     dfNumNormAll    MLPC_tanh_(5,5)           2   12.150476
# 27        dfNumOnly    MLPC_tanh_(5,5)           0   17.834378
# 28        dfNumOnly    MLPC_tanh_(5,5)           1    8.926209
# 29        dfNumOnly    MLPC_tanh_(5,5)           2   28.041805
# 30  dfNumOnly10Feat    MLPC_tanh_(5,5)           0   13.492485
# 31  dfNumOnly10Feat    MLPC_tanh_(5,5)           1    5.237496
# 32  dfNumOnly10Feat    MLPC_tanh_(5,5)           2   14.618054
# 33  dfNumOnly20Feat    MLPC_tanh_(5,5)           0    9.880512
# 34  dfNumOnly20Feat    MLPC_tanh_(5,5)           1   14.281829
# 35  dfNumOnly20Feat    MLPC_tanh_(5,5)           2   12.789633
# 36  dfNumOnly10Feat    MLPC_relu_(5,5)           0    9.297398
# 37  dfNumOnly10Feat    MLPC_relu_(5,5)           1    9.617404
# 38  dfNumOnly10Feat    MLPC_relu_(5,5)           2    7.808919
# 39  dfNumOnly20Feat    MLPC_relu_(5,5)           0   15.769910
# 40  dfNumOnly20Feat    MLPC_relu_(5,5)           1    6.485525
# 41  dfNumOnly20Feat    MLPC_relu_(5,5)           2   14.585541
# 42            dfNum  SVM_rbf_1200iters           0  121.958534
# 43            dfNum  SVM_rbf_1200iters           1  121.808880
# 44            dfNum  SVM_rbf_1200iters           2  123.715567
# 45        dfNumNorm  SVM_rbf_1200iters           0  112.377424
# 46        dfNumNorm  SVM_rbf_1200iters           1  121.046128
# 47        dfNumNorm  SVM_rbf_1200iters           2  120.474517
# 48     dfNumNormAll  SVM_rbf_1200iters           0  128.014413
# 49     dfNumNormAll  SVM_rbf_1200iters           1  149.902981
# 50     dfNumNormAll  SVM_rbf_1200iters           2  143.527901
# 51        dfNumOnly  SVM_rbf_1200iters           0  131.636339
# 52        dfNumOnly  SVM_rbf_1200iters           1  145.669283
# 53        dfNumOnly  SVM_rbf_1200iters           2  139.185205
# 54  dfNumOnly10Feat  SVM_rbf_1200iters           0   32.423787
# 55  dfNumOnly10Feat  SVM_rbf_1200iters           1   40.606542
# 56  dfNumOnly10Feat  SVM_rbf_1200iters           2   34.756317
# 57  dfNumOnly20Feat  SVM_rbf_1200iters           0   71.418150
# 58  dfNumOnly20Feat  SVM_rbf_1200iters           1   79.040702
# 59  dfNumOnly20Feat  SVM_rbf_1200iters           2   91.442893
#
#     PredictionTime  Precision   F1Score  RocAucScore
# 0         0.011567   0.947765  0.962071     0.990020
# 1         0.011524   0.945694  0.960377     0.988970
# 2         0.011698   0.948586  0.962762     0.989704
# 3         0.010796   0.946858  0.961363     0.989167
# 4         0.011641   0.946841  0.961317     0.989526
# 5         0.011820   0.946105  0.960879     0.989558
# 6         0.011243   0.947097  0.961631     0.988972
# 7         0.012318   0.947953  0.962111     0.989949
# 8         0.010902   0.946858  0.961212     0.989309
# 9         0.010430   0.946858  0.961327     0.989317
# 10        0.011600   0.946653  0.961319     0.989403
# 11        0.010696   0.947029  0.961371     0.989137
# 12        0.006313   0.936575  0.954501     0.982429
# 13        0.005904   0.935771  0.953914     0.982350
# 14        0.006025   0.935104  0.953533     0.981613
# 15        0.008071   0.940014  0.956612     0.984656
# 16        0.007667   0.939005  0.955877     0.984198
# 17        0.008557   0.937961  0.955418     0.983189
# 18        0.012943   0.938115  0.954492     0.985528
# 19        0.010571   0.936096  0.954661     0.986799
# 20        0.012569   0.936507  0.955388     0.985927
# 21        0.013022   0.937105  0.953196     0.986342
# 22        0.010516   0.934659  0.954326     0.984498
# 23        0.010589   0.934779  0.951717     0.985390
# 24        0.011176   0.935702  0.952734     0.985468
# 25        0.011845   0.939141  0.955952     0.986380
# 26        0.014718   0.939484  0.955994     0.985527
# 27        0.013629   0.934796  0.954196     0.985772
# 28        0.018890   0.936233  0.955128     0.985061
# 29        0.011246   0.940031  0.956307     0.987122
# 30        0.006779   0.929885  0.951114     0.979889
# 31        0.009552   0.935737  0.954730     0.971512
# 32        0.006777   0.934351  0.953680     0.980641
# 33        0.008231   0.934419  0.954182     0.986271
# 34        0.020550   0.936096  0.954403     0.986048
# 35        0.011735   0.935377  0.954633     0.985168
# 36        0.010419   0.935309  0.954548     0.979842
# 37        0.009483   0.934282  0.953902     0.968493
# 38        0.008499   0.927798  0.949602     0.967847
# 39        0.012909   0.938046  0.954826     0.985660
# 40        0.014364   0.936489  0.955261     0.985276
# 41        0.023679   0.936147  0.954844     0.981815
# 42        2.287595   0.547573  0.515119     0.789618
# 43        3.042531   0.623231  0.659091     0.792921
# 44        3.134110   0.699488  0.726503     0.918362
# 45        2.738135   0.719558  0.747469     0.165702
# 46        2.801070   0.772717  0.813553     0.908808
# 47        2.660627   0.758499  0.804547     0.128011
# 48        2.980967   0.514227  0.473149     0.795432
# 49        2.765719   0.495492  0.425328     0.783079
# 50        2.604083   0.780040  0.825312     0.177641
# 51        2.212968   0.355775  0.109921     0.892905
# 52        2.716702   0.514723  0.517086     0.738486
# 53        2.311712   0.535459  0.493196     0.769827
# 54        0.846998   0.660821  0.677480     0.084408
# 55        0.878684   0.519205  0.466724     0.278237
# 56        1.027513   0.534176  0.571339     0.299295
# 57        1.394463   0.556949  0.527541     0.844701
# 58        1.538389   0.666895  0.682517     0.177112
# 59        1.473617   0.629271  0.633615     0.806125

# %%
df2 = df.iloc[::3, :]
df2 = df2.reset_index()
df2 = df2.drop(['index'],axis=1)
df2
# Out:
#             Dataset         Classifier  KFoldIndex     FitTime  \
# 0             dfNum    DecTree MSF=100           0    1.075743
# 1         dfNumNorm    DecTree MSF=100           0    1.114521
# 2      dfNumNormAll    DecTree MSF=100           0    1.059332
# 3         dfNumOnly    DecTree MSF=100           0    1.069072
# 4   dfNumOnly10Feat    DecTree MSF=100           0    0.899927
# 5   dfNumOnly20Feat    DecTree MSF=100           0    2.093759
# 6             dfNum    MLPC_tanh_(5,5)           0    5.739113
# 7         dfNumNorm    MLPC_tanh_(5,5)           0    6.305877
# 8      dfNumNormAll    MLPC_tanh_(5,5)           0   15.123451
# 9         dfNumOnly    MLPC_tanh_(5,5)           0   17.834378
# 10  dfNumOnly10Feat    MLPC_tanh_(5,5)           0   13.492485
# 11  dfNumOnly20Feat    MLPC_tanh_(5,5)           0    9.880512
# 12  dfNumOnly10Feat    MLPC_relu_(5,5)           0    9.297398
# 13  dfNumOnly20Feat    MLPC_relu_(5,5)           0   15.769910
# 14            dfNum  SVM_rbf_1200iters           0  121.958534
# 15        dfNumNorm  SVM_rbf_1200iters           0  112.377424
# 16     dfNumNormAll  SVM_rbf_1200iters           0  128.014413
# 17        dfNumOnly  SVM_rbf_1200iters           0  131.636339
# 18  dfNumOnly10Feat  SVM_rbf_1200iters           0   32.423787
# 19  dfNumOnly20Feat  SVM_rbf_1200iters           0   71.418150
#
#     PredictionTime  Precision   F1Score  RocAucScore
# 0         0.011567   0.947765  0.962071     0.990020
# 1         0.010796   0.946858  0.961363     0.989167
# 2         0.011243   0.947097  0.961631     0.988972
# 3         0.010430   0.946858  0.961327     0.989317
# 4         0.006313   0.936575  0.954501     0.982429
# 5         0.008071   0.940014  0.956612     0.984656
# 6         0.012943   0.938115  0.954492     0.985528
# 7         0.013022   0.937105  0.953196     0.986342
# 8         0.011176   0.935702  0.952734     0.985468
# 9         0.013629   0.934796  0.954196     0.985772
# 10        0.006779   0.929885  0.951114     0.979889
# 11        0.008231   0.934419  0.954182     0.986271
# 12        0.010419   0.935309  0.954548     0.979842
# 13        0.012909   0.938046  0.954826     0.985660
# 14        2.287595   0.547573  0.515119     0.789618
# 15        2.738135   0.719558  0.747469     0.165702
# 16        2.980967   0.514227  0.473149     0.795432
# 17        2.212968   0.355775  0.109921     0.892905
# 18        0.846998   0.660821  0.677480     0.084408
# 19        1.394463   0.556949  0.527541     0.844701

# %%
plt.title('Fit Time (seconds)')
ax = sns.heatmap(df2.pivot(index='Dataset', columns='Classifier', values='FitTime'), annot=True, cmap="YlOrRd", fmt='.3g')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (6.0, 0.0)

# %%
plt.title('Prediction Time (seconds)')
ax = sns.heatmap(df2.pivot(index='Dataset', columns='Classifier', values='PredictionTime'), annot=True, cmap="YlOrRd",fmt='.3g')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (6.0, 0.0)

# %%
plt.title('Precision')
ax = sns.heatmap(df2.pivot(index='Dataset', columns='Classifier', values='Precision'), annot=True, cmap="RdYlGn",fmt='.3g')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (6.0, 0.0)

# %%
plt.title('F1 - Score')
ax = sns.heatmap(df2.pivot(index='Dataset', columns='Classifier', values='F1Score'), annot=True, cmap="RdYlGn",fmt='.3g')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (6.0, 0.0)

# %%
plt.title('F1 - Score')
ax = sns.heatmap(df2.pivot(index='Dataset', columns='Classifier', values='RocAucScore'), annot=True, cmap="RdYlGn",fmt='.3g')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (6.0, 0.0)
